# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
from sme_evolution import *

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='force', filt=None)

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='force', filt='kalman')

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='parametric', filt=None)

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='parametric', filt='kalman')

# %%
gamma_list = np.logspace(-3, 0.5, num=6)

# %%
effective_temp_plot(del_t=0.01,period_number=10000, eta=1, k=0.05, gamma_list=gamma_list, x0=20, p0=20, feedback='force', filt=None, plot_bool = True)
# Out:
# [np.float64(8.454120194622168e-05),
#  np.float64(2.6892702495976984e-05),
#  np.float64(5.564825690732396e-06),
#  np.float64(2.0662729397960164e-06),
#  np.float64(2.5377562991818767e-06),
#  np.float64(3.248713429485759e-05)]

# %%
#Compare different protocols with same eta and k vals

eta_list = [1,1,1,1]
k_list = [0.5,0.5,0.5]
feedback_list = ['force','force','parametric','parametric']
filt_list = [None, 'kalman', None, 'kalman']

# %%
comp_effective_temp_plot(del_t=0.01,period_number=10000, eta_list=eta_list, k_list=k_list, gamma_list=gamma_list, x0=20, p0=20, feedback_list= feedback_list, filt_list=filt_list)
# Out:
# [[np.float64(0.0010980905116119758),
#   np.float64(0.0003066172757406106),
#   np.float64(4.733488413584663e-05),
#   np.float64(1.0273452633291186e-05),
#   np.float64(3.076868724856255e-06),
#   np.float64(5.888261488653183e-06)],
#  [np.float64(9.772971287003905e-05),
#   np.float64(7.173572583164653e-05),
#   np.float64(3.360008281752928e-05),
#   np.float64(1.042758299553967e-05),
#   np.float64(4.119351128013297e-06),
#   np.float64(3.59012582841559e-06)],
#  [np.float64(0.0005795255090290934),
#   np.float64(0.00011320672033726428),
#   np.float64(2.5045122157673057e-05),
#   np.float64(6.775872045378472e-06),
#   np.float64(6.1543079207309365e-06),
#   np.float64(1.8218228130640322e-05)]]
