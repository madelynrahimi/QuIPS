# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
from sme_evolution_2d import *

# %%
plot_sme_traj_2D(del_t=0.001,period_number=100, eta=1, k=0.05, gamma=0.1, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', M=None, plot_bool=True)

# %%
gamma_list = np.logspace(-3, 0.5, num=6)

# %%
effective_temp_plot(del_t=0.001,period_number=100, eta=1, k=0.05, gamma_list=gamma_list, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', M= None, plot_bool = True)
# Out:
# [[np.float64(0.0001157556029098416),
#   np.float64(3.941995241673619e-05),
#   np.float64(1.3859381936975401e-05),
#   np.float64(2.858941260614342e-05),
#   np.float64(nan),
#   np.float64(nan)],
#  [np.float64(4.746113092808971e-05),
#   np.float64(4.546349222129761e-06),
#   np.float64(1.4456952530265424e-06),
#   np.float64(2.314147579577052e-05),
#   np.float64(nan),
#   np.float64(nan)]]

# %%
plot_sme_traj_2D(del_t=0.001,period_number=100, eta=1, k=0.05, gamma=0.1, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman',fx = 5e4, fy=5e4, M=None, plot_bool=True)
