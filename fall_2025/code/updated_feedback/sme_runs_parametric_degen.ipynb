# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
from sme_evolution_2d import *

# %%
plot_sme_traj_2D(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.1, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', M=None, plot_bool=True)

# %%
gamma_list = np.logspace(-3, 0.5, num=6)

# %%
effective_temp_plot(del_t=0.01,period_number=100, eta=1, k=0.05, gamma_list=gamma_list, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', M= None, plot_bool = True)
# Out:
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:196: RuntimeWarning: overflow encountered in matmul
#   p_sq = Vpp + p @ p.T
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:185: RuntimeWarning: overflow encountered in matmul
#   p += (-K@x) *del_t -8*eta*k* (Vxp.T@x)*del_t + 2*(Vxp.T@del_Q)
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:189: RuntimeWarning: overflow encountered in matmul
#   Vpp += ((-K@Vxp - Vxp.T@K) +2*k - 8*eta*k*(Vxp@Vxp.T)) * del_t
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:190: RuntimeWarning: invalid value encountered in matmul
#   Vxp += (M_inv@Vpp - Vxx@K -8*eta*k*(Vxx@Vxp)) * del_t
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:190: RuntimeWarning: overflow encountered in matmul
#   Vxp += (M_inv@Vpp - Vxx@K -8*eta*k*(Vxx@Vxp)) * del_t
# ...

# %%
plot_sme_traj_2D(del_t=0.001,period_number=100, eta=1, k=0.05, gamma=0.1, x0=[30,20], p0=[40,10], feedback='parametric', filt='kalman',fx = 5e4, fy=5e4, M=None, plot_bool=True)

# %%
gamma = 2.51188643e-02

# %%
effective_temp_plot_degen(del_t=0.001,period_number=100, eta=1, k=0.05, gamma=gamma, x0=[20,30], p0=[10,40],feedback='parametric', filt='kalman', fx = 1e4, fy = 5e4, plot_bool = True)
# Out:
# [[np.float64(2.0943836266337438e-07),
#   np.float64(5.85979450005898e-07),
#   np.float64(3.608197006713532e-07),
#   np.float64(4.4528901332887897e-07),
#   np.float64(4.984327166364798e-07),
#   np.float64(4.972893943654579e-07),
#   np.float64(6.140321700846525e-07),
#   np.float64(6.88977101883846e-07),
#   np.float64(6.60156028723304e-07),
#   np.float64(4.512834102308996e-05)],
#  [np.float64(1.0870266513145814e-06),
#   np.float64(1.5468099529481037e-06),
#   np.float64(8.682950463698233e-07),
#   np.float64(7.939657373565661e-07),
#   np.float64(1.1248366078056864e-06),
#   np.float64(5.963081025039443e-07),
#   np.float64(8.442949592893567e-07),
#   np.float64(1.037113839055401e-06),
#   np.float64(1.0132411596970922e-06),
#   np.float64(0.00019839330456866575)]]

# %%
plot_sme_traj_2D(del_t=0.001,period_number=100, eta=1, k=0.05, gamma=0.1, x0=[20,30], p0=[10,40], feedback='parametric', filt='kalman',fx = 5e4, fy=5e4, M=None, plot_bool=True)

# %%
#ensemble average, simulate overa  bunch of trajectories and then average over the trajectories 
#can then get temperature as a function of time then change parameters fit an exponential and then get the rate of cooling see if it matches for dave's parater

# %%
#primciples of nanooptics by novotony
