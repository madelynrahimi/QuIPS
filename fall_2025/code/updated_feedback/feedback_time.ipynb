# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
from sme_evolution import *

# %%
feedback_time_plot(del_t=0.001,period_number=100, eta=0.05, k=0.1, gamma=0.01, x0=20, p0=20, feedback="force", traj_num=100, filt=None)

# %%
feedback_time_plot(del_t=0.001,period_number=100, eta=0.05, k=0.1, gamma=0.01, x0=20, p0=20, feedback="force", traj_num=100, filt='kalman')

# %%
feedback_time_plot(del_t=0.001,period_number=50, eta=0.05, k=0.1, gamma=0.01, x0=20, p0=20, feedback="parametric", traj_num=100, filt='kalman')

# %%
cooling_rate_calc(del_t=0.001,period_number=100, eta=0.05, k=0.1, gamma=0.01, x0=20, p0=20, n_bins = 1000, feedback="force", traj_num=100, filt='kalman',plot_bool= False)
# Out:
# Time to feedback cool 329.85 microseconds
# array([1.43933500e-05, 6.46120515e-04, 3.03168117e+03])

# %%
T_eff, A, cooling_rate = cooling_rate_calc(del_t=0.001,period_number=100, eta=0.05, k=0.1, gamma=0.01, x0=20, p0=20, n_bins = 100, feedback="force", traj_num=100, filt='kalman',plot_bool= True)
# Out:
# Time to feedback cool 328.15 microseconds

# %%
# Out:
# Time to feedback cool 158.62 microseconds

# %%
T_eff, A, cooling_rate = cooling_rate_calc(del_t=0.001,period_number=100, eta=0.05, k=0.1, gamma=0.01, x0=40, p0=40, n_bins = 100, feedback="force", traj_num=100, filt=None,plot_bool= True)
# Out:
# Time to feedback cool 319.13 microseconds

# %%
T_eff, A, cooling_rate = cooling_rate_calc(del_t=0.001,period_number=50, eta=1, k=0.1, gamma=0.01, x0=20, p0=20, n_bins = 100, feedback="parametric", traj_num=100, filt='kalman',plot_bool= True)
# Out:
# Time to feedback cool 160.88 microseconds

# %%
T_eff, A, cooling_rate = cooling_rate_calc(del_t=0.001,period_number=50, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, n_bins = 100, feedback="parametric", traj_num=100, filt='kalman',plot_bool= True)
# Out:
# Time to feedback cool 159.92 microseconds

# %%
T_eff, A, cooling_rate = cooling_rate_calc(del_t=0.001,period_number=50, eta=0.05, k=0.1, gamma=0.1, x0=20, p0=20, n_bins = 100, feedback="parametric", traj_num=100, filt='kalman',plot_bool= True)
# Out:
# Time to feedback cool 16.20 microseconds
