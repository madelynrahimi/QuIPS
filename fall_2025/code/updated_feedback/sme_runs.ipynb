# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
from sme_evolution import *

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='force', filt=None)

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='force', filt='kalman')

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='parametric', filt=None)

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=0.01, k=0.1, gamma=0.01, x0=20, p0=20, feedback='parametric', filt='kalman')

# %%
gamma_list = np.logspace(-3, 0.5, num=6)

# %%
effective_temp_plot(del_t=0.001,period_number=10000, eta=0.05, k=0.1, gamma_list=gamma_list, x0=20, p0=20, feedback='parametric', filt=None, plot_bool = True)
# Out:
# [np.float64(9.102349488313106e-05),
#  np.float64(3.001033896893868e-05),
#  np.float64(1.1589704929455583e-05),
#  np.float64(1.106632840949192e-05),
#  np.float64(2.0819971767175502e-05),
#  np.float64(nan)]

# %%
#Compare different protocols with same eta and k vals and occupation number plots 

eta_list = [1,1,1,1]
k_list = [0.05,0.05,0.05,0.05]
feedback_list = ['force','force','parametric','parametric']
filt_list = [None, 'kalman', None, 'kalman']

# %%
comp_effective_temp_plot(del_t=0.01,period_number=20000, eta_list=eta_list, k_list=k_list, gamma_list=gamma_list, x0=20, p0=20, feedback_list= feedback_list, filt_list=filt_list)
# Out:
# [[np.float64(0.000150229426205511),
#   np.float64(2.4678849131446224e-05),
#   np.float64(5.570702074776296e-06),
#   np.float64(2.0837520607824e-06),
#   np.float64(2.5422691424097864e-06),
#   np.float64(3.247264700044679e-05)],
#  [np.float64(0.0001034789066717913),
#   np.float64(2.1018484582061192e-05),
#   np.float64(6.190747125048922e-06),
#   np.float64(2.191560005770037e-06),
#   np.float64(1.4440524142980375e-06),
#   np.float64(1.4442349244414337e-06)],
#  [np.float64(6.19287050988045e-05),
#   np.float64(1.3721364142626957e-05),
#   np.float64(3.7464371689714333e-06),
#   np.float64(2.380440315577086e-06),
#   np.float64(4.269152870681644e-06),
#   np.float64(nan)],
#  [np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan)]]

# %%
#eta 0.05 and k0.1
