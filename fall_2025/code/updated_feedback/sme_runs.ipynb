# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
from sme_evolution import *

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='force', filt=None)

# %%
plot_sme_traj(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='force', filt='kalman')

# %%
plot_sme_traj(del_t=0.001,period_number=1000, eta=1, k=0.05, gamma=0.01, x0=20, p0=20, feedback='parametric', filt=None)

# %%
plot_sme_traj(del_t=0.001,period_number=100, eta=0.01, k=0.1, gamma=0.01, x0=20, p0=20, feedback='parametric', filt='kalman')

# %%
gamma_list = np.logspace(-3, 0.5, num=6)

# %%
effective_temp_plot(del_t=0.001,period_number=10000, eta=0.05, k=0.1, gamma_list=gamma_list, x0=20, p0=20, feedback='parametric', filt='kalman', plot_bool = True)
# Out:
# [np.float64(0.00014923518511275277),
#  np.float64(3.099324991248546e-05),
#  np.float64(1.1704836307723113e-05),
#  np.float64(1.0917311619230637e-05),
#  np.float64(2.1046908862553615e-05),
#  np.float64(nan)]

# %%
#Compare different protocols with same eta and k vals and occupation number plots 

eta_list = [1,1,1]
k_list = [0.05,0.05,0.05]
feedback_list = ['force','force','parametric']
filt_list = [None, 'kalman', 'kalman']

# %%
comp_effective_temp_plot(del_t=0.01,period_number=20000, eta_list=eta_list, k_list=k_list, gamma_list=gamma_list, x0=20, p0=20, feedback_list= feedback_list, filt_list=filt_list)
# Out:
# [[np.float64(0.00010189084908074141),
#   np.float64(2.450712449428047e-05),
#   np.float64(6.0879832015316186e-06),
#   np.float64(2.067494888050027e-06),
#   np.float64(2.5451087585468942e-06),
#   np.float64(3.24603331611056e-05)],
#  [np.float64(8.089494140527873e-05),
#   np.float64(2.2233663261176608e-05),
#   np.float64(6.072038009923318e-06),
#   np.float64(2.1698319079202833e-06),
#   np.float64(1.4414835833758272e-06),
#   np.float64(1.4424124370232062e-06)],
#  [np.float64(6.572844527700726e-05),
#   np.float64(1.2908770359535744e-05),
#   np.float64(3.890380619595225e-06),
#   np.float64(2.374574201807165e-06),
#   np.float64(4.142315135210137e-06),
#   np.float64(nan)]]

# %%
#eta 0.05 and k0.1

# %%
eta_list = [0.05,0.05,0.05]
k_list = [0.05,0.1,0.5]
feedback_list = ['parametric','parametric','parametric']
filt_list = ['kalman', 'kalman', 'kalman']

# %%
comp_effective_temp_plot(del_t=0.01,period_number=20000, eta_list=eta_list, k_list=k_list, gamma_list=gamma_list, x0=20, p0=20, feedback_list= feedback_list, filt_list=filt_list)
# Out:
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:137: RuntimeWarning: overflow encountered in scalar power
#   p_sq = var_p + p**2
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:128: RuntimeWarning: overflow encountered in scalar multiply
#   p += (-m* w_sq*x*del_t) -8*eta*k*x*cov_xp*del_t + 2*cov_xp*del_Q
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:133: RuntimeWarning: overflow encountered in scalar power
#   var_p += ((-2*m*w_sq*cov_xp) + 2*k - (8*eta*k*cov_xp**2)) * del_t
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:134: RuntimeWarning: overflow encountered in scalar multiply
#   cov_xp += (1/m*var_p - m*w_sq*var_x - (8*eta*k*var_x*cov_xp)) *del_t
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:134: RuntimeWarning: invalid value encountered in scalar subtract
#   cov_xp += (1/m*var_p - m*w_sq*var_x - (8*eta*k*var_x*cov_xp)) *del_t
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:136: RuntimeWarning: overflow encountered in scalar power
#   x_sq = var_x + x**2
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:137: RuntimeWarning: invalid value encountered in scalar add
#   p_sq = var_p + p**2
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:127: RuntimeWarning: overflow encountered in scalar multiply
#   x += (1/m*p*del_t) -8*eta*k*x*var_x*del_t + 2*var_x*del_Q
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:127: RuntimeWarning: invalid value encountered in scalar subtract
#   x += (1/m*p*del_t) -8*eta*k*x*var_x*del_t + 2*var_x*del_Q
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:132: RuntimeWarning: overflow encountered in scalar power
#   var_x += ((2/m*cov_xp) - (8*eta*k*var_x**2)) * del_t
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution.py:128: RuntimeWarning: invalid value encountered in scalar add
#   p += (-m* w_sq*x*del_t) -8*eta*k*x*cov_xp*del_t + 2*cov_xp*del_Q
# [[np.float64(7.867287281914909e-05),
#   np.float64(1.7134095695907513e-05),
#   np.float64(1.0404285581324374e-05),
#   np.float64(1.1791123630060532e-05),
#   np.float64(nan),
#   np.float64(nan)],
#  [np.float64(0.00011748065909318653),
#   np.float64(3.185646713594675e-05),
#   np.float64(1.1701034703831118e-05),
#   np.float64(1.0716503494962686e-05),
#   np.float64(nan),
#   np.float64(nan)],
#  [np.float64(0.0004295885491769749),
#   np.float64(0.00011220664177788164),
#   np.float64(3.0600937519582724e-05),
#   np.float64(1.2329398345691587e-05),
#   np.float64(1.9583237099385385e-05),
#   np.float64(nan)]]
