# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
from sme_evolution_2d import *

# %%
plot_sme_traj_2D(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=[20,20], p0=[20,20], feedback='force', filt=None, M=None)

# %%
plot_sme_traj_2D(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=[20,20], p0=[20,20], feedback='force', filt='kalman', M=None)

# %%
plot_sme_traj_2D(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', M=None)

# %%
gamma_list = np.logspace(-3, 0.5, num=6)

# %%
effective_temp_plot(del_t=0.01,period_number=10000, eta=0.05, k=0.1, gamma_list=gamma_list, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', M= None, plot_bool = True)
# Out:
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:185: RuntimeWarning: overflow encountered in matmul
#   p_sq = Vpp + p @ p.T
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:176: RuntimeWarning: overflow encountered in matmul
#   p += (-K@x) *del_t -8*eta*k* (Vxp.T@x)*del_t + 2*(Vxp.T@del_Q)
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:176: RuntimeWarning: invalid value encountered in add
#   p += (-K@x) *del_t -8*eta*k* (Vxp.T@x)*del_t + 2*(Vxp.T@del_Q)
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:180: RuntimeWarning: overflow encountered in matmul
#   Vpp += ((-K@Vxp - Vxp.T@K) +2*k - 8*eta*k*(Vxp@Vxp.T)) * del_t
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:181: RuntimeWarning: invalid value encountered in matmul
#   Vxp += (M_inv@Vpp - Vxx@K -8*eta*k*(Vxx@Vxp)) * del_t
# ...
