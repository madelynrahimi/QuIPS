# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit
from sme_evolution_2d import *

# %%
plot_sme_traj_2D(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=[20,20], p0=[20,20], feedback='force', filt=None, M=None)

# %%
plot_sme_traj_2D(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=[20,20], p0=[20,20], feedback='force', filt='kalman', M=None)

# %%
plot_sme_traj_2D(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', M=None)

# %%
gamma_list = np.logspace(-3, 0.5, num=6)

# %%
gamma_list
# Out:
# array([1.00000000e-03, 5.01187234e-03, 2.51188643e-02, 1.25892541e-01,
#        6.30957344e-01, 3.16227766e+00])

# %%
effective_temp_plot(del_t=0.01,period_number=100, eta=1, k=0.05, gamma_list=gamma_list, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', M= None, plot_bool = True)
# Out:
# [[np.float64(0.00014000822365693193),
#   np.float64(1.098739236219529e-05),
#   np.float64(7.179636385602314e-06),
#   np.float64(4.3769074091709785e-05),
#   np.float64(nan),
#   np.float64(nan)],
#  [np.float64(5.663652160941078e-05),
#   np.float64(7.622356166993033e-06),
#   np.float64(3.050394597424303e-06),
#   np.float64(2.3392991108500736e-05),
#   np.float64(nan),
#   np.float64(nan)]]

# %%
fx = 10000
fy = 50000

# %%
gamma = 2.51188643e-02

# %%
effective_temp_plot_degen(del_t=0.01,period_number=1000, eta=1, k=0.05, gamma=gamma, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', fx = 1e4, fy = 5e4, plot_bool = True)
# Out:
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:188: RuntimeWarning: invalid value encountered in add
#   p_sq = Vpp + p @ p.T
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:178: RuntimeWarning: invalid value encountered in matmul
#   x += (M_inv@p)*del_t -8*eta*k*(Vxx@x)*del_t + 2*(Vxx@del_Q)
# /Users/madelynrahimi/Desktop/QMG/updated_feedback/sme_evolution_2d.py:234: RuntimeWarning: invalid value encountered in matmul
#   exp_p_real = exp_p @ Sp.T
# [[np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(7.57349773107697e-06),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan)],
#  [np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(4.595323462658236e-05),
#   np.float64(nan),
#   np.float64(nan),
#   np.float64(nan)]]

# %%
plot_sme_traj_2D(del_t=0.01,period_number=100, eta=1, k=0.05, gamma=0.01, x0=[20,20], p0=[20,20], feedback='parametric', filt='kalman', fx= 1e4, fy= (1e4*0.5848035476425733))

# %%
ratio_list= []
pairs = [
(np.sqrt(fx*fy) * (fx/fy)**((1-s)/2),
 np.sqrt(fx*fy) / (fx/fy)**((1-s)/2))
for s in np.linspace(0,1,10)]

for pair in pairs:
    fx, fy = pair
    ratio_list.append(fx/fy)

# %%
ratio_list
# Out:
# [np.float64(0.2),
#  np.float64(0.23916263490008044),
#  np.float64(0.2859938296617457),
#  np.float64(0.34199518933533934),
#  np.float64(0.40896235302295825),
#  np.float64(0.4890425696195377),
#  np.float64(0.5848035476425733),
#  np.float64(0.6993157867655625),
#  np.float64(0.8362510309503733),
#  np.float64(1.0)]
